# %% [markdown]
# ### Évaluation et Comparaison des Modèles

# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split

df = pd.read_csv("../data/processed/cleaned_data.csv")

X = df.drop(columns=["charges"])
y = df["charges"]

X_train, X_test, y_train, y_test = train_test_split(
    X, y, test_size=0.2, random_state=474
)

y_train = np.log1p(y_train)
y_test = np.log1p(y_test)

# %%
import matplotlib.pyplot as plt
import joblib

rf_model = joblib.load("../models/RandomForest_final.pkl")

y_pred_rf = rf_model.predict(X_test)



# Scatter plot: Actual vs Predicted
plt.figure(figsize=(6, 5))
plt.scatter(y_test, y_pred_rf, alpha=0.6, color="blue")
plt.plot([y_test.min(), y_test.max()], [y_test.min(), y_test.max()], 'r--')
plt.xlabel("Actual values")
plt.ylabel("Predicted values")
plt.title("Random Forest - Actual vs Predicted")
plt.show()
residuals_rf = abs(y_test - y_pred_rf)
plt.figure(figsize=(6, 5))
plt.scatter(y_pred_rf, residuals_rf, alpha=0.6, color="green")
plt.axhline(0, color="red", linestyle="--")
plt.xlabel("Predicted values")
plt.ylabel("Residuals")
plt.title("Random Forest - Residual Plot")
plt.show()

# %%
# Load model
xgb_model = joblib.load("../models/XGBoost_Final.pkl")

# Predictions
y_pred_xgb = xgb_model.predict(X_test)

# Scatter plot: Actual vs Predicted
plt.figure(figsize=(6, 5))
plt.scatter(y_test, y_pred_xgb, alpha=0.6, color="orange")
plt.plot([y_test.min(), y_test.max()], [y_test.min(), y_test.max()], 'r--')
plt.xlabel("Actual values")
plt.ylabel("Predicted values")
plt.title("XGBoost - Actual vs Predicted")
plt.show()

# Residual plot
residuals_xgb = abs(y_test - y_pred_rf)
plt.figure(figsize=(6, 5))
plt.scatter(y_pred_xgb, residuals_xgb, alpha=0.6, color="purple")
plt.axhline(0, color="red", linestyle="--")
plt.xlabel("Predicted values")
plt.ylabel("Residuals")
plt.title("XGBoost - Residual Plot")
plt.show()

# %%
# Load model
svr_model = joblib.load("../models/SVR_Final.pkl")

# Predictions
y_pred_svr = svr_model.predict(X_test)

# Scatter plot: Actual vs Predicted
plt.figure(figsize=(6, 5))
plt.scatter(y_test, y_pred_svr, alpha=0.6, color="orange")
plt.plot([y_test.min(), y_test.max()], [y_test.min(), y_test.max()], 'r--')
plt.xlabel("Actual values")
plt.ylabel("Predicted values")
plt.title("svroost - Actual vs Predicted")
plt.show()

# Residual plot
residuals_svr = abs(y_test - y_pred_rf)
plt.figure(figsize=(6, 5))
plt.scatter(y_pred_svr, residuals_svr, alpha=0.6, color="purple")
plt.axhline(0, color="red", linestyle="--")
plt.xlabel("Predicted values")
plt.ylabel("Residuals")
plt.title("svroost - Residual Plot")
plt.show()
